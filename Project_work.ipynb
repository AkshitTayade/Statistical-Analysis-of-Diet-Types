# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from order_of_magnitude import order_of_magnitude
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from itertools import combinations

from scipy.stats import mannwhitneyu, wilcoxon, kruskal
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from scikit_posthocs import posthoc_nemenyi_friedman, posthoc_nemenyi
from scipy.stats import chi2, chi2_contingency, chisquare
from scipy.stats import shapiro
from pingouin import multivariate_normality

from fitter import Fitter, get_common_distributions, get_distributions
from distfit import distfit
from scipy.stats import kstest, ks_2samp
import statsmodels.api as sm

from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Exercise.xlsx')
df.columns = list(df.iloc[0, :].values)
df.drop(index=0, inplace=True)
df.drop('Name', axis=1, inplace=True)
df.head()
# Out:
#   Gender Age  ... Calorie Difference (Daily Calorie Intake - TDEE)                Suggestion
# 1   Male  18  ...                                            -0.03  LOW CARB DIET (25:35:40)
# 2   Male  18  ...                                            -0.23   BALANCE DIET (55:25:20)
# 3   Male  18  ...                                            -0.18   BALANCE DIET (55:25:20)
# 4   Male  18  ...                                        -0.271667  KETOGENIC DIET (5:35:60)
# 5   Male  18  ...                                            -0.26   BALANCE DIET (55:25:20)
#
# [5 rows x 18 columns]

# %%
df.shape
# Out:
# (10080, 18)

# %%
type(df.iloc[0,0]), type(df.iloc[0,1])
# Out:
# (str, int)

# %%
print( "Order of magnitude:", order_of_magnitude.order_of_magnitude( [df['Daily Calories Intake'].max(), df['Body Mass Index (BMI)'].max()] ) )
# Out:
# Order of magnitude: [3, 1]

# %% [markdown]
# ### Convert categorical to numerical

# %%
# Mapping String to numeric values.
df['Gender']=df['Gender'].map({"Male":0,"Female":1})
df['Body Type']=df['Body Type'].map({"Underweight":0,"Normal":1,"Overweight":2,"Obese":3})
df['Type']=df['Type'].map({"Boy":0,"Girl":1,"Adult Male":2,"Adult Female":3})
df['Suggestion']=df['Suggestion'].map({"LOW CARB DIET (25:35:40)":0,"BALANCE DIET (55:25:20)":1,"ZONE DIET (40:30:30)":2,"KETOGENIC DIET (5:35:60)":3,"DEPLETION DIET (DYNAMIC)":4,"HIGH CARB DIET(60:20:20)":5})
df['Target']=df['Target'].map({"Loose Weight":0,"Maintain Weight":1,"Gain Muscle":2})
df['Lifestyle']=df['Lifestyle'].map({"1. Sedentary or light activity (e.g. - Office worker getting little or no exercise)":0,"2. Active or moderately active (Construction worker or person running one hour daily)":1,"3. Vigorously active (Agricultural worker (non mechanized) or person swimming two hours daily)":2})
df['Exercise']=df['Exercise'].map({"1. Sedentary (little or no exercise)":0,"2. Lightly active (light exercise/sports 1-3 days/ week)":1,"3. Moderately active (moderate exercise/sports 3-5days/week)":2,"4. Very active (hard exercise/sports 6-7 days a week)":3})

# %%
df
# Out:
#        Gender Age  ... Calorie Difference (Daily Calorie Intake - TDEE) Suggestion
# 1           0  18  ...                                            -0.03          0
# 2           0  18  ...                                            -0.23          1
# 3           0  18  ...                                            -0.18          1
# 4           0  18  ...                                        -0.271667          3
# 5           0  18  ...                                            -0.26          1
# ...       ...  ..  ...                                              ...        ...
# 10076       1  65  ...                                             0.22          1
# 10077       1  65  ...                                             0.16          5
# 10078       1  65  ...                                            -0.22          0
# 10079       1  65  ...                                            -0.09          2
# 10080       1  65  ...                                              0.1          2
#
# [10080 rows x 18 columns]

# %%
df = df.apply(pd.to_numeric)

# %%
type(df.iloc[0,0]), type(df.iloc[0,1])
# Out:
# (numpy.int64, numpy.int64)

# %% [raw]
# # Comparing Two Samples:
# 1. Parametric Test - Z, T test | Method Based on Normal Distribution
# 2. Non-Parametric Test - Man-Whitney | Wilcoxon Sign Rank
#
# #Comparing more than Two Samples:
# 1. Parametric Test - F test
# 2. Non-Parametric Test - KW Test
#
# *To check which pairs are not equal - Tukey's or Bonferroni

# %% [markdown]
# ### Check for Null value in dataset

# %%
df.isnull().sum()
# Out:
# Gender                                                                              0
# Age                                                                                 0
# Height(cm)                                                                          0
# Weight(kg)                                                                          0
# Lifestyle                                                                           0
# Exercise                                                                            0
# Daily Calories Intake                                                               0
# Target                                                                              0
# How motivated are you for being healthy\n(in %)                                     0
# Body Mass Index (BMI)                                                               0
# Basal Metabolic Rate (BMR)                                                          0
# Type                                                                                0
# Body Fat Percentage (BFP)                                                           0
# Body Type                                                                           0
# Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)                        0
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)    0
# Calorie Difference (Daily Calorie Intake - TDEE)                                    0
# Suggestion                                                                          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Gender                                                                              0
# Age                                                                                 0
# Height(cm)                                                                          0
# Weight(kg)                                                                          0
# Lifestyle                                                                           0
# Exercise                                                                            0
# Daily Calories Intake                                                               0
# Target                                                                              0
# How motivated are you for being healthy\n(in %)                                     0
# Body Mass Index (BMI)                                                               0
# Basal Metabolic Rate (BMR)                                                          0
# Type                                                                                0
# Body Fat Percentage (BFP)                                                           0
# Body Type                                                                           0
# Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)                        0
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)    0
# Calorie Difference (Daily Calorie Intake - TDEE)                                    0
# Suggestion                                                                          0
# dtype: int64

# %% [markdown]
# ### Checking Correlation

# %%
plt.figure(figsize=(22, 15))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

print(to_drop)

# Drop features 
df.drop(to_drop, axis=1, inplace=True)
# Out:
# ['Body Type']

# %%
## checking correlation after normalizing the data
df_scaled = StandardScaler().fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled
# Out:
#        Gender       Age  ...  Calorie Difference (Daily Calorie Intake - TDEE)  Suggestion
# 0        -1.0 -1.704309  ...                                         -0.168609   -1.113972
# 1        -1.0 -1.704309  ...                                         -1.307818   -0.439284
# 2        -1.0 -1.704309  ...                                         -1.023016   -0.439284
# 3        -1.0 -1.704309  ...                                         -1.545153    0.910093
# 4        -1.0 -1.704309  ...                                         -1.478699   -0.439284
# ...       ...       ...  ...                                               ...         ...
# 10075     1.0  1.565182  ...                                          1.255402   -0.439284
# 10076     1.0  1.565182  ...                                          0.913640    2.259470
# 10077     1.0  1.565182  ...                                         -1.250857   -1.113972
# 10078     1.0  1.565182  ...                                         -0.510371    0.235405
# 10079     1.0  1.565182  ...                                          0.571877    0.235405
#
# [10080 rows x 17 columns]

# %%
plt.figure(figsize=(22, 15))
sns.heatmap(df_scaled.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Univariate Analysis
#     - Performing Shaprio test before using any Non-parametric Test

# %% [raw]
# H0 = The variables follow a univariate normal distribution
# H1 = oppose H0

# %%
def HypoTesting_Uni(pvalue, alpha = 0.05):
    if pvalue < alpha:
        return("Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)")
    else:
        return("Failed to Reject H0 (i.e., The variables follow a univariate normal distribution)*****")

# %%
for col in df_scaled.columns:
    test = shapiro(df_scaled[col])
    print("{} - {}".format(col, HypoTesting_Uni(test.pvalue)))
# Out:
# Gender - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Age - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Height(cm) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Weight(kg) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Lifestyle - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Exercise - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Daily Calories Intake - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Target - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# How motivated are you for being healthy
# (in %) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Body Mass Index (BMI) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Basal Metabolic Rate (BMR) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Type - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Body Fat Percentage (BFP) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Calorie Difference (Daily Calorie Intake - TDEE) - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)
# Suggestion - Rejcting H0 (i.e., The variables don't follow a univariate normal distribution)

# %% [raw]
# After performing Shapiro test,
# we can say that none of the columns follow a normal distribution pattern
# and hence we can proceed with either Man Whitney or Wilcoxon Sign Test

# %% [markdown]
# ## Comparing Two Samples
#     - Performing Non-Parametric Test - Man Whitney

# %% [raw]
# stats, pvalue = mannwhitneyu(df['Suggestion'], df_scaled['Daily Calories Intake'])
# print('Statistics={}, p-value={}'.format(stats, pvalue))

# %%
# conditioning to see if both sample come from same distribution
# H0 : mean1=mean2
# H1 : opposite H0
# If p-valu< α, then reject H0 (Mod 5 - Slide 9)

def HypoTesting(pvalue, alpha = 0.05):
    if pvalue < alpha:
        return("Rejcting H0 (i.e., They do not belong to same distribution)")
    else:
        return("Failed to Reject H0 (i.e., They belong to same distribution)*****")

# %%
for i in df.columns[:-1]:
    stats, pvalue = mannwhitneyu(df_scaled[str(i)].values, df_scaled['Suggestion'].values)
    print('{} vs Suggestion: Statistics={}, p-value={}'.format(i, stats, pvalue))
    print('{} vs Suggestion:'.format(i), HypoTesting(pvalue))
    print()
# Out:
# Gender vs Suggestion: Statistics=55535760.0, p-value=1.4284687575242532e-31
# Gender vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Age vs Suggestion: Statistics=50053248.0, p-value=0.0681289782444675
# Age vs Suggestion: Failed to Reject H0 (i.e., They belong to same distribution)*****
#
# Height(cm) vs Suggestion: Statistics=55314000.0, p-value=4.525032465219178e-28
# Height(cm) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Weight(kg) vs Suggestion: Statistics=52887960.0, p-value=4.0130628436200426e-07
# Weight(kg) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Lifestyle vs Suggestion: Statistics=49091776.0, p-value=2.7916767131174795e-05
# Lifestyle vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Exercise vs Suggestion: Statistics=49094528.0, p-value=3.043038832318388e-05
# Exercise vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Daily Calories Intake vs Suggestion: Statistics=51899890.0, p-value=0.007676229977428326
# Daily Calories Intake vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Target vs Suggestion: Statistics=49082880.0, p-value=2.5356220535525184e-05
# Target vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# How motivated are you for being healthy
# (in %) vs Suggestion: Statistics=52336040.0, p-value=0.00019421292739845374
# How motivated are you for being healthy
# (in %) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Body Mass Index (BMI) vs Suggestion: Statistics=52277100.0, p-value=0.0003397067442572709
# Body Mass Index (BMI) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Basal Metabolic Rate (BMR) vs Suggestion: Statistics=52134309.0, p-value=0.0012128209938833475
# Basal Metabolic Rate (BMR) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Type vs Suggestion: Statistics=48933360.0, p-value=4.062024259408968e-06
# Type vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Body Fat Percentage (BFP) vs Suggestion: Statistics=53233167.0, p-value=3.481659848038369e-09
# Body Fat Percentage (BFP) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie) vs Suggestion: Statistics=52324555.0, p-value=0.0002170272596296129
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie) vs Suggestion: Statistics=51794833.0, p-value=0.01592625609894477
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Calorie Difference (Daily Calorie Intake - TDEE) vs Suggestion: Statistics=52263526.0, p-value=0.00038527628113584994
# Calorie Difference (Daily Calorie Intake - TDEE) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Suggestion'], kde=True)
# Out:
# <AxesSubplot:xlabel='Suggestion', ylabel='Count'>

# %% [raw]
# ## Identifying the distribution
#
# get_dist = Fitter(df_scaled['Age'].values, distributions=get_common_distributions())
# get_dist.fit()
# get_dist.summary()

# %% [raw]
# ## Identifying the distribution
#
# get_dist = Fitter(df_scaled['Suggestion'].values, distributions=get_common_distributions())
# get_dist.fit()
# get_dist.summary()

# %%
dist_age = distfit(distr=get_common_distributions())
dist_age.fit_transform(df_scaled[['Age', 'Suggestion']].values)
print(dist_age.summary)
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[cauchy  ] [0.01 sec] [RSS: 11.0409] [loc=-0.214 scale=0.620]
# [distfit] >[chi2    ] [0.16 sec] [RSS: 14.5557] [loc=-1.704 scale=1.027]
# [distfit] >[expon   ] [0.0 sec] [RSS: 11.5406] [loc=-1.704 scale=1.704]
# [distfit] >[exponpow] [0.29 sec] [RSS: 10.6254] [loc=-1.733 scale=2.729]
# [distfit] >[gamma   ] [0.06 sec] [RSS: 10.5758] [loc=-2.193 scale=0.484]
# [distfit] >[lognorm ] [0.14 sec] [RSS: 10.5989] [loc=-3.261 scale=3.112]
# [distfit] >[norm    ] [0.0 sec] [RSS: 10.7722] [loc=-0.000 scale=1.000]
# [distfit] >[powerlaw] [0.14 sec] [RSS: 11.0603] [loc=-1.704 scale=3.982]
# [distfit] >[rayleigh] [0.01 sec] [RSS: 10.5837] [loc=-1.879 scale=1.505]
# [distfit] >[uniform ] [0.0 sec] [RSS: 11.0569] [loc=-1.704 scale=3.964]
# [distfit] >Compute confidence interval [parametric]
#       distr      score  LLE       loc     scale                     arg
# 0     gamma  10.575817  NaN -2.192926  0.484065    (4.530230890611492,)
# 1  rayleigh  10.583659  NaN -1.878903  1.505038                      ()
# 2   lognorm  10.598943  NaN -3.261399  3.111826  (0.30826183611575964,)
# 3  exponpow  10.625436  NaN -1.732511  2.728986   (1.2680361305270962,)
# 4      norm  10.772238  NaN      -0.0       1.0                      ()
# 5    cauchy  11.040939  NaN -0.213862  0.619952                      ()
# 6   uniform  11.056942  NaN -1.704309  3.963779                      ()
# 7  powerlaw  11.060311  NaN -1.704309  3.982379   (0.8524746968803434,)
# 8     expon   11.54057  NaN -1.704309  1.704309                      ()
# 9      chi2  14.555692  NaN -1.704309  1.026844   (1.1966303284200688,)

# %% [raw]
# Assuming that Age, Suggestion may belong to Gamma Distribution
# This is further proved by Tukey's Test in One way ANOVA

# %% [markdown]
# ## Comparing Two Samples
#     - Performing Non-Parametric Test - Wilcoxon Sign Rank Test

# %%
# find difference between Suggestion and rest of the columns

for i in df.columns[:-1]:
    diff = df_scaled[i].values - df['Suggestion'].values
    res_wil = wilcoxon(diff)
    print('{} vs Suggestion: Statistics={}, p-value={}'.format(i, res_wil.statistic, res_wil.pvalue))
    print('{} vs Suggestion:'.format(i), HypoTesting(res_wil.pvalue))
    print()
# Out:
# Gender vs Suggestion: Statistics=1484759.0, p-value=0.0
# Gender vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Age vs Suggestion: Statistics=4518565.5, p-value=0.0
# Age vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Height(cm) vs Suggestion: Statistics=3943978.0, p-value=0.0
# Height(cm) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Weight(kg) vs Suggestion: Statistics=4187350.5, p-value=0.0
# Weight(kg) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Lifestyle vs Suggestion: Statistics=4595142.0, p-value=0.0
# Lifestyle vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Exercise vs Suggestion: Statistics=3229858.0, p-value=0.0
# Exercise vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Daily Calories Intake vs Suggestion: Statistics=4413551.0, p-value=0.0
# Daily Calories Intake vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Target vs Suggestion: Statistics=15225.0, p-value=0.0
# Target vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# How motivated are you for being healthy
# (in %) vs Suggestion: Statistics=2280331.0, p-value=0.0
# How motivated are you for being healthy
# (in %) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Body Mass Index (BMI) vs Suggestion: Statistics=4308564.0, p-value=0.0
# Body Mass Index (BMI) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Basal Metabolic Rate (BMR) vs Suggestion: Statistics=4170345.0, p-value=0.0
# Basal Metabolic Rate (BMR) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Type vs Suggestion: Statistics=3081773.0, p-value=0.0
# Type vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Body Fat Percentage (BFP) vs Suggestion: Statistics=4223410.0, p-value=0.0
# Body Fat Percentage (BFP) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie) vs Suggestion: Statistics=4140580.0, p-value=0.0
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie) vs Suggestion: Statistics=4209128.0, p-value=0.0
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)
#
# Calorie Difference (Daily Calorie Intake - TDEE) vs Suggestion: Statistics=4371481.0, p-value=0.0
# Calorie Difference (Daily Calorie Intake - TDEE) vs Suggestion: Rejcting H0 (i.e., They do not belong to same distribution)

# %% [markdown]
# ## Multivariate Analysis

# %% [raw]
# H0 = The variables follow a multivariate normal distribution
# H1 = oppose H0

# %%
def HypoTesting_Multi(pvalue, alpha = 0.05):
    if pvalue < alpha:
        return("Rejcting H0 (i.e., The variables don't follow a multivariate normal distribution)")
    else:
        return("Failed to Reject H0 (i.e., The variables follow a multivariate normal distribution)*****")

# %%
test_multi = multivariate_normality(df_scaled)
test_multi
# Out:
# HZResults(hz=3.084945844896956, pval=0.0, normal=False)

# %%
HypoTesting_Multi(test_multi.pval)
# Out:
# "Rejcting H0 (i.e., The variables don't follow a multivariate normal distribution)"

# %% [raw]
# After performing Multivariate_normality test,
# we can say that the data as whole don not come from normal distribution
# and hence we can proceed with Krushal Wallis Test

# %% [markdown]
# ## Comparing More than two Samples
#     - Performing Non-Parametric Test - KW Test

# %%
df_scaled.shape
# Out:
# (10080, 17)

# %%
# conditioning to see if n samples come from same distribution
# H0 : mean1=mean2=mean3......=meanN
# H1 : opposite H0
# If p-valu< α, then reject H0 

def HypoTesting(pvalue, alpha = 0.05):
    if pvalue < alpha:
        return("Rejecting H0 (i.e., They don't have the same means)")
    else:
        return("Failed to Reject H0 (i.e., They have the same means)*****")

# %%
stat, pvalue = kruskal(df_scaled.iloc[:, 0],
                      df_scaled.iloc[:, 1],
                      df_scaled.iloc[:, 2],
                      df_scaled.iloc[:, 3],
                      df_scaled.iloc[:, 4],
                      df_scaled.iloc[:, 5],
                      df_scaled.iloc[:, 6],
                      df_scaled.iloc[:, 7],
                      df_scaled.iloc[:, 8],
                      df_scaled.iloc[:, 9],
                      df_scaled.iloc[:, 10],
                      df_scaled.iloc[:, 11],
                      df_scaled.iloc[:, 12],
                      df_scaled.iloc[:, 13],
                      df_scaled.iloc[:, 14],
                      df_scaled.iloc[:, 15],
                      df_scaled.iloc[:, 16])

print(HypoTesting(pvalue))
# Out:
# Rejecting H0 (i.e., They don't have the same means)

# %%
df_new = pd.read_excel('Exercise.xlsx')
df_new.columns = list(df_new.iloc[0, :].values)
df_new.drop(index=0, inplace=True)
df_new.drop('Name', axis=1, inplace=True)
df_new.head()
# Out:
#   Gender Age  ... Calorie Difference (Daily Calorie Intake - TDEE)                Suggestion
# 1   Male  18  ...                                            -0.03  LOW CARB DIET (25:35:40)
# 2   Male  18  ...                                            -0.23   BALANCE DIET (55:25:20)
# 3   Male  18  ...                                            -0.18   BALANCE DIET (55:25:20)
# 4   Male  18  ...                                        -0.271667  KETOGENIC DIET (5:35:60)
# 5   Male  18  ...                                            -0.26   BALANCE DIET (55:25:20)
#
# [5 rows x 18 columns]

# %%
df_new['Suggestion'].unique(), len(df_new['Suggestion'].unique())
# Out:
# (array(['LOW CARB DIET (25:35:40)', 'BALANCE DIET (55:25:20)',
#         'KETOGENIC DIET (5:35:60)', 'HIGH CARB DIET(60:20:20)',
#         'ZONE DIET (40:30:30)', 'DEPLETION DIET (DYNAMIC)'], dtype=object),
#  6)

# %% [markdown]
# ## Nemenyi's Test

# %% [raw]
# H0 = No significant difference between the means of two groups
# H1 = oppose H0

# %%
nemenyi = posthoc_nemenyi(np.array([df_scaled['Age'].values, df_new['Suggestion'].values]).T)
nemenyi
# Out:
#                           BALANCE DIET (55:25:20)  ...  ZONE DIET (40:30:30)
# BALANCE DIET (55:25:20)                  1.000000  ...              0.996381
# DEPLETION DIET (DYNAMIC)                 0.453439  ...              0.406377
# HIGH CARB DIET(60:20:20)                 0.700857  ...              0.921993
# KETOGENIC DIET (5:35:60)                 0.998839  ...              1.000000
# LOW CARB DIET (25:35:40)                 0.841354  ...              0.987238
# ZONE DIET (40:30:30)                     0.996381  ...              1.000000
#
# [6 rows x 6 columns]

# %% [raw]
# tukey = pairwise_tukeyhsd(endog=df_scaled['Age'], groups=df_new['Suggestion'], alpha=0.05)
# tukey._results_table
#
# # if reject = False -> NO statistically significant difference between the means of groups

# %%
id_low = df_new[df_new['Suggestion'] == 'LOW CARB DIET (25:35:40)'].index
id_low
# Out:
# Int64Index([    1,     7,    13,    16,    22,    31,    37,    40,    46,
#                52,
#             ...
#             10015, 10021, 10022, 10030, 10045, 10052, 10060, 10066, 10075,
#             10078],
#            dtype='int64', length=2123)

# %%
id_balanced = df_new[df_new['Suggestion'] == 'BALANCE DIET (55:25:20)'].index
id_balanced
# Out:
# Int64Index([    2,     3,     5,     8,    11,    14,    17,    20,    23,
#                26,
#             ...
#             10057, 10058, 10061, 10064, 10067, 10069, 10070, 10072, 10073,
#             10076],
#            dtype='int64', length=3589)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_low, 1])

print("No difference in the means")

plt.xlabel("Age")
plt.ylabel("Count")
plt.title("LOW CARB DIET")
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_balanced, 1])

plt.xlabel("Age")
plt.ylabel("Count")
plt.title("BALANCE DIET")
plt.show()
# Out:
# No difference in the means

# %%
nemenyi = posthoc_nemenyi(np.array([df_scaled['Daily Calories Intake'].values, df_new['Suggestion'].values]).T)
nemenyi
# Out:
#                           BALANCE DIET (55:25:20)  ...  ZONE DIET (40:30:30)
# BALANCE DIET (55:25:20)              1.000000e+00  ...          3.987428e-78
# DEPLETION DIET (DYNAMIC)             6.740926e-11  ...          7.955119e-04
# HIGH CARB DIET(60:20:20)             9.275220e-01  ...          1.566790e-48
# KETOGENIC DIET (5:35:60)             5.000191e-46  ...          6.589030e-01
# LOW CARB DIET (25:35:40)             3.700934e-75  ...          9.998936e-01
# ZONE DIET (40:30:30)                 3.987428e-78  ...          1.000000e+00
#
# [6 rows x 6 columns]

# %% [raw]
# tukey = pairwise_tukeyhsd(endog=df_scaled['Daily Calories Intake'], groups=df_new['Suggestion'], alpha=0.05)
# tukey._results_table

# %%
id_high = df_new[df_new['Suggestion'] == 'HIGH CARB DIET(60:20:20)'].index
id_high
# Out:
# Int64Index([    6,    18,    24,    30,    36,    39,    45,    48,    51,
#                54,
#             ...
#              9999, 10008, 10011, 10026, 10029, 10053, 10056, 10071, 10074,
#             10077],
#            dtype='int64', length=1151)

# %%
id_keto = df_new[df_new['Suggestion'] == 'KETOGENIC DIET (5:35:60)'].index
id_keto
# Out:
# Int64Index([    4,    10,    19,    25,    28,    34,    49,    55,    82,
#                88,
#             ...
#              9982, 10003, 10006, 10018, 10024, 10033, 10036, 10048, 10051,
#             10063],
#            dtype='int64', length=799)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_high, 6], kde=True)

print("No difference in the means")

plt.xlabel("Daily Calories Intake")
plt.ylabel("Count")
plt.title("HIGH CARB DIET")
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_balanced, 6], kde=True)

plt.xlabel("Daily Calories Intake")
plt.ylabel("Count")
plt.title("BALANCE DIET")
plt.show()
# Out:
# No difference in the means

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_high, 6], kde=True)

print("There is difference in the means")

plt.xlabel("Daily Calories Intake")
plt.ylabel("Count")
plt.title("HIGH CARB DIET")
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_keto, 6], kde=True)

plt.xlabel("Daily Calories Intake")
plt.ylabel("Count")
plt.title("KETO DIET")
plt.show()
# Out:
# There is difference in the means

# %%
nemenyi = posthoc_nemenyi(np.array([df_scaled['Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)'].values, df_new['Suggestion'].values]).T)
nemenyi
# Out:
#                           BALANCE DIET (55:25:20)  ...  ZONE DIET (40:30:30)
# BALANCE DIET (55:25:20)              1.000000e+00  ...          1.169404e-28
# DEPLETION DIET (DYNAMIC)             7.668021e-03  ...          4.536798e-01
# HIGH CARB DIET(60:20:20)             1.365045e-03  ...          9.697109e-04
# KETOGENIC DIET (5:35:60)             3.275007e-53  ...          2.792525e-11
# LOW CARB DIET (25:35:40)             1.486854e-48  ...          2.912763e-02
# ZONE DIET (40:30:30)                 1.169404e-28  ...          1.000000e+00
#
# [6 rows x 6 columns]

# %% [raw]
# tukey = pairwise_tukeyhsd(endog=df_scaled['Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)'], groups=df_new['Suggestion'], alpha=0.05)
# tukey._results_table

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_balanced, 15], kde=True)

print("There is difference in the means")

plt.xlabel("TDEE")
plt.ylabel("Count")
plt.title("BALANCED DIET")
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_keto, 15], kde=True)

plt.xlabel("TDEE")
plt.ylabel("Count")
plt.title("KETO DIET")
plt.show()
# Out:
# There is difference in the means

# %%
id_dep = df_new[df_new['Suggestion'] == 'DEPLETION DIET (DYNAMIC)'].index
id_dep
# Out:
# Int64Index([  56,   92,   97,   98,  106,  107,  205,  344,  427,  515,  629,
#              949, 1451, 1817, 1954, 2672, 3260, 3556, 3802, 4070, 4139, 4642,
#             4772, 5515, 6061, 6229, 6493, 6577, 6860, 7531, 8509, 8860, 9506],
#            dtype='int64')

# %%
id_zone = df_new[df_new['Suggestion'] == 'ZONE DIET (40:30:30)'].index
id_zone
# Out:
# Int64Index([    9,    12,    15,    21,    27,    33,    35,    42,    50,
#                57,
#             ...
#             10041, 10044, 10047, 10050, 10059, 10062, 10065, 10068, 10079,
#             10080],
#            dtype='int64', length=2385)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_dep, 15], kde=True)

print("No difference in the means")

plt.xlabel("TDEE")
plt.ylabel("Count")
plt.title("DEPLETION DIET")
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(df_new.iloc[id_keto, 15], kde=True)

plt.xlabel("TDEE")
plt.ylabel("Count")
plt.title("KETO DIET")
plt.show()
# Out:
# No difference in the means

# %% [markdown]
# ## Categorical Analysis
#     - Performing Chi-square test of independence

# %%
df_new.head(2)
# Out:
#   Gender Age Height(cm) Weight(kg)  \
# 1   Male  18        152         50
# 2   Male  18        152         54
#
#                                            Lifestyle  \
# 1  1. Sedentary or light activity (e.g. - Office ...
# 2  1. Sedentary or light activity (e.g. - Office ...
#
#                                             Exercise Daily Calories Intake  \
# 1               1. Sedentary (little or no exercise)           2067.152431
# 2  2. Lightly active (light exercise/sports 1-3 d...           1705.730935
#
#             Target How motivated are you for being healthy\n(in %)  \
# 1     Loose Weight                                              80
# 2  Maintain Weight                                              78
#
#   Body Mass Index (BMI) Basal Metabolic Rate (BMR) Type  \
# 1             21.641274                   1392.866  Boy
# 2             23.372576                   1447.866  Boy
#
#   Body Fat Percentage (BFP) Body Type  \
# 1                 17.878324    Normal
# 2                  20.49259    Normal
#
#   Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)  \
# 1                                          1671.4392
# 2                                         1990.81575
#
#   Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)  \
# 1                                         2131.08498
# 2                                         2215.23498
#
#   Calorie Difference (Daily Calorie Intake - TDEE)                Suggestion
# 1                                            -0.03  LOW CARB DIET (25:35:40)
# 2                                            -0.23   BALANCE DIET (55:25:20)

# %%
df_new.columns
# Out:
# Index(['Gender', 'Age', 'Height(cm)', 'Weight(kg)', 'Lifestyle', 'Exercise',
#        'Daily Calories Intake', 'Target',
#        'How motivated are you for being healthy\n(in %)',
#        'Body Mass Index (BMI)', 'Basal Metabolic Rate (BMR)', 'Type',
#        'Body Fat Percentage (BFP)', 'Body Type',
#        'Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)',
#        'Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)',
#        'Calorie Difference (Daily Calorie Intake - TDEE)', 'Suggestion'],
#       dtype='object')

# %%
# categorical columns = Lifestyle, Suggestion, Target, Body Type

chisq_test_1 = pd.crosstab(df_new['Exercise'], df_new['Suggestion'])
chisq_test_1
# Out:
# Suggestion                                          BALANCE DIET (55:25:20)  \
# Exercise
# 1. Sedentary (little or no exercise)                                    945
# 2. Lightly active (light exercise/sports 1-3 da...                      904
# 3. Moderately active (moderate exercise/sports ...                      764
# 4. Very active (hard exercise/sports 6-7 days a...                      976
#
# Suggestion                                          DEPLETION DIET (DYNAMIC)  \
# Exercise
# 1. Sedentary (little or no exercise)                                       8
# 2. Lightly active (light exercise/sports 1-3 da...                         4
# 3. Moderately active (moderate exercise/sports ...                        12
# 4. Very active (hard exercise/sports 6-7 days a...                         9
#
# Suggestion                                          HIGH CARB DIET(60:20:20)  \
# Exercise
# 1. Sedentary (little or no exercise)                                     235
# 2. Lightly active (light exercise/sports 1-3 da...                       305
# 3. Moderately active (moderate exercise/sports ...                       308
# 4. Very active (hard exercise/sports 6-7 days a...                       303
#
# Suggestion                                          KETOGENIC DIET (5:35:60)  \
# Exercise
# 1. Sedentary (little or no exercise)                                     228
# 2. Lightly active (light exercise/sports 1-3 da...                       149
# 3. Moderately active (moderate exercise/sports ...                       208
# 4. Very active (hard exercise/sports 6-7 days a...                       214
#
# Suggestion                                          LOW CARB DIET (25:35:40)  \
# Exercise
# 1. Sedentary (little or no exercise)                                     548
# 2. Lightly active (light exercise/sports 1-3 da...                       459
# 3. Moderately active (moderate exercise/sports ...                       552
# 4. Very active (hard exercise/sports 6-7 days a...                       564
#
# Suggestion                                          ZONE DIET (40:30:30)
# Exercise
# 1. Sedentary (little or no exercise)                                 500
# 2. Lightly active (light exercise/sports 1-3 da...                   643
# 3. Moderately active (moderate exercise/sports ...                   620
# 4. Very active (hard exercise/sports 6-7 days a...                   622

# %%
stat, p, dof, expected = chi2_contingency(chisq_test_1)
print(stat, p)
# Out:
# 85.80798443723344 5.963255839629829e-12

# %%
if p < 0.05:
    print("Reject - H0: (null hypothesis) The two variables are independent.")
else:
    print("Failed to Reject H0")
# Out:
# Reject - H0: (null hypothesis) The two variables are independent.

# %%
chisq_test_2 = pd.crosstab(df_new['Lifestyle'], df_new['Suggestion'])
stat, p, dof, expected = chi2_contingency(chisq_test_2)
print(stat, p)

if p < 0.05:
    print("Reject - H0: (null hypothesis) The two variables are independent.")
else:
    print("Failed to Reject H0")
# Out:
# 11.593036223543177 0.3132156769579751
# Failed to Reject H0

# %%
chisq_test_2
# Out:
# Suggestion                                          BALANCE DIET (55:25:20)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                     1191
# 2. Active or moderately active (Construction wo...                     1197
# 3. Vigorously active (Agricultural worker (non ...                     1201
#
# Suggestion                                          DEPLETION DIET (DYNAMIC)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                        18
# 2. Active or moderately active (Construction wo...                         6
# 3. Vigorously active (Agricultural worker (non ...                         9
#
# Suggestion                                          HIGH CARB DIET(60:20:20)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                       361
# 2. Active or moderately active (Construction wo...                       404
# 3. Vigorously active (Agricultural worker (non ...                       386
#
# Suggestion                                          KETOGENIC DIET (5:35:60)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                       260
# 2. Active or moderately active (Construction wo...                       277
# 3. Vigorously active (Agricultural worker (non ...                       262
#
# Suggestion                                          LOW CARB DIET (25:35:40)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                       711
# 2. Active or moderately active (Construction wo...                       695
# 3. Vigorously active (Agricultural worker (non ...                       717
#
# Suggestion                                          ZONE DIET (40:30:30)
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                   818
# 2. Active or moderately active (Construction wo...                   781
# 3. Vigorously active (Agricultural worker (non ...                   786

# %%
chisq_test_3 = pd.crosstab(df_new['Lifestyle'], df_new['Exercise'])
stat, p, dof, expected = chi2_contingency(chisq_test_3)
print(stat, p)

if p < 0.05:
    print("Reject - H0: (null hypothesis) The two variables are independent.")
else:
    print("Failed to Reject H0")
# Out:
# 0.029233343365515432 0.9999994852041799
# Failed to Reject H0

# %%
chisq_test_3
# Out:
# Exercise                                            1. Sedentary (little or no exercise)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                                   822
# 2. Active or moderately active (Construction wo...                                   822
# 3. Vigorously active (Agricultural worker (non ...                                   820
#
# Exercise                                            2. Lightly active (light exercise/sports 1-3 days/ week)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                                                822
# 2. Active or moderately active (Construction wo...                                                822
# 3. Vigorously active (Agricultural worker (non ...                                                820
#
# Exercise                                            3. Moderately active (moderate exercise/sports 3-5days/week)  \
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                                                822
# 2. Active or moderately active (Construction wo...                                                820
# 3. Vigorously active (Agricultural worker (non ...                                                822
#
# Exercise                                            4. Very active (hard exercise/sports 6-7 days a week)
# Lifestyle
# 1. Sedentary or light activity (e.g. - Office w...                                                893
# 2. Active or moderately active (Construction wo...                                                896
# 3. Vigorously active (Agricultural worker (non ...                                                899

# %%
chisq_test_4 = pd.crosstab(df_new['Target'], df_new['Suggestion'])
stat, p, dof, expected = chi2_contingency(chisq_test_4)
print(stat, p)

if p < 0.05:
    print("Reject - H0: (null hypothesis) The two variables are independent.")
else:
    print("Failed to Reject H0")
# Out:
# 12540.08841237544 0.0
# Reject - H0: (null hypothesis) The two variables are independent.

# %%
chisq_test_4
# Out:
# Suggestion       BALANCE DIET (55:25:20)  DEPLETION DIET (DYNAMIC)  \
# Target
# Gain Muscle                          174                         0
# Loose Weight                         720                        17
# Maintain Weight                     2695                        16
#
# Suggestion       HIGH CARB DIET(60:20:20)  KETOGENIC DIET (5:35:60)  \
# Target
# Gain Muscle                          1151                         0
# Loose Weight                            0                       799
# Maintain Weight                         0                         0
#
# Suggestion       LOW CARB DIET (25:35:40)  ZONE DIET (40:30:30)
# Target
# Gain Muscle                             0                  2035
# Loose Weight                         1824                     0
# Maintain Weight                       299                   350

# %%
chisq_test_5 = pd.crosstab(df_new['Target'], df_new['Lifestyle'])
stat, p, dof, expected = chi2_contingency(chisq_test_5)
print(stat, p)

if p < 0.05:
    print("Reject - H0: (null hypothesis) The two variables are independent.")
else:
    print("Failed to Reject H0")
# Out:
# 0.0011904762959251253 0.9999998229160573
# Failed to Reject H0

# %%
chisq_test_5
# Out:
# Lifestyle        1. Sedentary or light activity (e.g. - Office worker getting little or no exercise)  \
# Target
# Gain Muscle                                                   1120
# Loose Weight                                                  1119
# Maintain Weight                                               1120
#
# Lifestyle        2. Active or moderately active (Construction worker or person running one hour daily)  \
# Target
# Gain Muscle                                                   1120
# Loose Weight                                                  1120
# Maintain Weight                                               1120
#
# Lifestyle        3. Vigorously active (Agricultural worker (non mechanized) or person swimming two hours daily)
# Target
# Gain Muscle                                                   1120
# Loose Weight                                                  1121
# Maintain Weight                                               1120

# %% [markdown]
# ## Selecting 'n' best features using SelectKBest()
#     - Using F values of ANOVA (F-Test)

# %%
data = pd.read_excel('Exercise.xlsx')
data.columns = list(data.iloc[0, :].values)
data.drop(index=0, inplace=True)
data.drop('Name', axis=1, inplace=True)
data.head()
# Out:
#   Gender Age Height(cm) Weight(kg)  \
# 1   Male  18        152         50
# 2   Male  18        152         54
# 3   Male  18        152         58
# 4   Male  18        152         62
# 5   Male  18        152         66
#
#                                            Lifestyle  \
# 1  1. Sedentary or light activity (e.g. - Office ...
# 2  1. Sedentary or light activity (e.g. - Office ...
# 3  1. Sedentary or light activity (e.g. - Office ...
# 4  3. Vigorously active (Agricultural worker (non...
# 5  1. Sedentary or light activity (e.g. - Office ...
#
#                                             Exercise Daily Calories Intake  \
# 1               1. Sedentary (little or no exercise)           2067.152431
# 2  2. Lightly active (light exercise/sports 1-3 d...           1705.730935
# 3  3. Moderately active (moderate exercise/sports...           1910.142686
# 4  4. Very active (hard exercise/sports 6-7 days ...           2552.952908
# 5               1. Sedentary (little or no exercise)           1826.086885
#
#             Target How motivated are you for being healthy\n(in %)  \
# 1     Loose Weight                                              80
# 2  Maintain Weight                                              78
# 3      Gain Muscle                                              65
# 4     Loose Weight                                              82
# 5  Maintain Weight                                              75
#
#   Body Mass Index (BMI) Basal Metabolic Rate (BMR) Type  \
# 1             21.641274                   1392.866  Boy
# 2             23.372576                   1447.866  Boy
# 3             25.103878                   1502.866  Boy
# 4              26.83518                   1557.866  Boy
# 5             28.566482                   1612.866  Boy
#
#   Body Fat Percentage (BFP)   Body Type  \
# 1                 17.878324      Normal
# 2                  20.49259      Normal
# 3                 23.106856  Overweight
# 4                 25.721122  Overweight
# 5                 28.335388  Overweight
#
#   Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)  \
# 1                                          1671.4392
# 2                                         1990.81575
# 3                                          2329.4423
# 4                                         2687.31885
# 5                                          1935.4392
#
#   Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)  \
# 1                                         2131.08498
# 2                                         2215.23498
# 3                                         2299.38498
# 4                                          3505.1985
# 5                                         2467.68498
#
#   Calorie Difference (Daily Calorie Intake - TDEE)                Suggestion
# 1                                            -0.03  LOW CARB DIET (25:35:40)
# 2                                            -0.23   BALANCE DIET (55:25:20)
# 3                                            -0.18   BALANCE DIET (55:25:20)
# 4                                        -0.271667  KETOGENIC DIET (5:35:60)
# 5                                            -0.26   BALANCE DIET (55:25:20)

# %%
# Mapping String to numeric values.
data['Gender']=data['Gender'].map({"Male":0,"Female":1})
data['Body Type']=data['Body Type'].map({"Underweight":0,"Normal":1,"Overweight":2,"Obese":3})
data['Type']=data['Type'].map({"Boy":0,"Girl":1,"Adult Male":2,"Adult Female":3})
data['Suggestion']=data['Suggestion'].map({"LOW CARB DIET (25:35:40)":0,"BALANCE DIET (55:25:20)":1,"ZONE DIET (40:30:30)":2,"KETOGENIC DIET (5:35:60)":3,"DEPLETION DIET (DYNAMIC)":4,"HIGH CARB DIET(60:20:20)":5})
data['Target']=data['Target'].map({"Loose Weight":0,"Maintain Weight":1,"Gain Muscle":2})
data['Lifestyle']=data['Lifestyle'].map({"1. Sedentary or light activity (e.g. - Office worker getting little or no exercise)":0,"2. Active or moderately active (Construction worker or person running one hour daily)":1,"3. Vigorously active (Agricultural worker (non mechanized) or person swimming two hours daily)":2})
data['Exercise']=data['Exercise'].map({"1. Sedentary (little or no exercise)":0,"2. Lightly active (light exercise/sports 1-3 days/ week)":1,"3. Moderately active (moderate exercise/sports 3-5days/week)":2,"4. Very active (hard exercise/sports 6-7 days a week)":3})

# %%
data = data.apply(pd.to_numeric)

# %%
X = data.iloc[:, :-1]
X.shape
# Out:
# (10080, 17)

# %%
Y = data.iloc[:, -1]
Y.shape
# Out:
# (10080,)

# %%
sc_scaler = StandardScaler()
X = sc_scaler.fit_transform(X)
X.shape
# Out:
# (10080, 17)

# %%
X = pd.DataFrame(X, columns=list(data.columns)[:-1])
X
# Out:
#        Gender       Age  Height(cm)  Weight(kg)  Lifestyle  Exercise  \
# 0        -1.0 -1.704309    -1.46385   -1.243933  -1.224988 -1.360019
# 1        -1.0 -1.704309    -1.46385   -1.006993  -1.224988 -0.473050
# 2        -1.0 -1.704309    -1.46385   -0.770054  -1.224988  0.413919
# 3        -1.0 -1.704309    -1.46385   -0.533114   1.224502  1.300887
# 4        -1.0 -1.704309    -1.46385   -0.296174  -1.224988 -1.360019
# ...       ...       ...         ...         ...        ...       ...
# 10075     1.0  1.565182     1.46385    0.296174   1.224502  1.300887
# 10076     1.0  1.565182     1.46385    0.533114   1.224502 -1.360019
# 10077     1.0  1.565182     1.46385    0.770054   1.224502 -0.473050
# 10078     1.0  1.565182     1.46385    1.006993   1.224502  0.413919
# 10079     1.0  1.565182     1.46385    1.243933   1.224502  1.300887
#
#        Daily Calories Intake    Target  \
# 0                  -0.948266 -1.224745
# 1                  -1.385131  0.000000
# 2                  -1.138050  1.224745
# 3                  -0.361060 -1.224745
# 4                  -1.239652  0.000000
# ...                      ...       ...
# 10075               1.246541  0.000000
# 10076               1.136394  1.224745
# 10077              -0.283890 -1.224745
# 10078               0.337951  0.000000
# 10079               1.242633  1.224745
#
#        How motivated are you for being healthy\n(in %)  Body Mass Index (BMI)  \
# 0                                             0.237504              -0.592030
# 1                                             0.043670              -0.342490
# 2                                            -1.216250              -0.092950
# 3                                             0.431338               0.156589
# 4                                            -0.247081               0.406129
# ...                                                ...                    ...
# 10075                                         1.109757              -0.404250
# 10076                                         1.303591              -0.230196
# 10077                                        -0.731665              -0.056142
# 10078                                         0.915923               0.117912
# 10079                                        -1.700835               0.291966
#
#        Basal Metabolic Rate (BMR)      Type  Body Fat Percentage (BFP)  \
# 0                       -0.541999 -3.618136                  -1.298428
# 1                       -0.321641 -3.618136                  -1.017369
# 2                       -0.101283 -3.618136                  -0.736309
# 3                        0.119074 -3.618136                  -0.455250
# 4                        0.339432 -3.618136                  -0.174191
# ...                           ...       ...                        ...
# 10075                   -0.455130  0.904534                   0.766252
# 10076                   -0.301873  0.904534                   0.922045
# 10077                   -0.148616  0.904534                   1.077837
# 10078                    0.004641  0.904534                   1.233630
# 10079                    0.157897  0.904534                   1.389422
#
#        Body Type  \
# 0      -0.607181
# 1      -0.607181
# 2       0.346150
# 3       0.346150
# 4       0.346150
# ...          ...
# 10075  -0.607181
# 10076  -0.607181
# 10077   0.346150
# 10078   0.346150
# 10079   0.346150
#
#        Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)  \
# 0                                              -1.199687
# 1                                              -0.530306
# 2                                               0.179420
# 3                                               0.929492
# 4                                              -0.646370
# ...                                                  ...
# 10075                                           0.411337
# 10076                                          -1.048948
# 10077                                          -0.405851
# 10078                                           0.265307
# 10079                                           0.964525
#
#        Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)  \
# 0                                              -1.055461
# 1                                              -0.926927
# 2                                              -0.798394
# 3                                               1.043408
# 4                                              -0.541326
# ...                                                  ...
# 10075                                           0.550863
# 10076                                           0.682325
# 10077                                           0.813787
# 10078                                           0.945249
# 10079                                           1.076710
#
#        Calorie Difference (Daily Calorie Intake - TDEE)
# 0                                             -0.168609
# 1                                             -1.307818
# 2                                             -1.023016
# 3                                             -1.545153
# 4                                             -1.478699
# ...                                                 ...
# 10075                                          1.255402
# 10076                                          0.913640
# 10077                                         -1.250857
# 10078                                         -0.510371
# 10079                                          0.571877
#
# [10080 rows x 17 columns]

# %%
for i in range(10, 16):
    select_clf = SelectKBest(score_func=f_classif, k=i)
    select_clf.fit(X, Y)
    new_X = X.iloc[:,select_clf.get_support()]
    
    x_train, x_test, y_train, y_test = train_test_split(new_X, data.iloc[:, -1], test_size=0.2, random_state=1)
    
    log_reg = sm.MNLogit(y_train.values.ravel(), x_train).fit()
    
    clf = LogisticRegression(C=10, multi_class='multinomial', n_jobs=-1).fit(x_train, y_train)
    
    print("Features = {}, AIC = {}, Train Acc = {}, Test Acc = {}".format(i, log_reg.aic, accuracy_score(y_train, clf.predict(x_train)), accuracy_score(y_test, clf.predict(x_test))))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.993554
#          Iterations 8
# Features = 10, AIC = 16124.0336195591, Train Acc = 0.8551587301587301, Test Acc = 0.8571428571428571
# Optimization terminated successfully.
#          Current function value: 0.978977
#          Iterations 8
# Features = 11, AIC = 15898.947466843001, Train Acc = 0.8611111111111112, Test Acc = 0.8650793650793651
# Optimization terminated successfully.
#          Current function value: 0.974188
#          Iterations 8
# Features = 12, AIC = 15831.698119278528, Train Acc = 0.8587549603174603, Test Acc = 0.8621031746031746
# Optimization terminated successfully.
#          Current function value: 0.972083
#          Iterations 8
# Features = 13, AIC = 15807.746588902739, Train Acc = 0.8586309523809523, Test Acc = 0.8635912698412699
# Optimization terminated successfully.
#          Current function value: 0.971832
#          Iterations 8
# Features = 14, AIC = 15813.700787090916, Train Acc = 0.8588789682539683, Test Acc = 0.8616071428571429
# Optimization terminated successfully.
#          Current function value: 0.971074
#          Iterations 8
# Features = 15, AIC = 15811.475032070164, Train Acc = 0.8587549603174603, Test Acc = 0.8611111111111112

# %%
x_train, x_test, y_train, y_test = train_test_split(X, data.iloc[:, -1], test_size=0.2, random_state=1)

# %%
select_clf = SelectKBest(score_func=f_classif, k=13)
select_clf.fit(x_train, y_train)
# Out:
# SelectKBest(k=13)

# %%
kept_features = pd.DataFrame({'Columns': X.columns,
                              'Kept': select_clf.get_support()})
kept_features
# Out:
#                                               Columns  Kept
# 0                                              Gender  True
# 1                                          Height(cm)  True
# 2                                          Weight(kg)  True
# 3                               Daily Calories Intake  True
# 4                                              Target  True
# 5     How motivated are you for being healthy\n(in %)  True
# 6                               Body Mass Index (BMI)  True
# 7                          Basal Metabolic Rate (BMR)  True
# 8                           Body Fat Percentage (BFP)  True
# 9                                           Body Type  True
# 10  Daily Calorie Need (Based on BMR and Exercise)...  True
# 11  Total Daily Energy Expenditure (TDEE) (Based o...  True
# 12   Calorie Difference (Daily Calorie Intake - TDEE)  True

# %% [raw]
# With SelectKbest method, n=13 features gave lowest AIC and satisfactory accuracy

# %%
X = X.iloc[:, select_clf.get_support()]
X
# Out:
#        Gender  Height(cm)  Weight(kg)  Daily Calories Intake    Target  \
# 0        -1.0    -1.46385   -1.243933              -0.948266 -1.224745
# 1        -1.0    -1.46385   -1.006993              -1.385131  0.000000
# 2        -1.0    -1.46385   -0.770054              -1.138050  1.224745
# 3        -1.0    -1.46385   -0.533114              -0.361060 -1.224745
# 4        -1.0    -1.46385   -0.296174              -1.239652  0.000000
# ...       ...         ...         ...                    ...       ...
# 10075     1.0     1.46385    0.296174               1.246541  0.000000
# 10076     1.0     1.46385    0.533114               1.136394  1.224745
# 10077     1.0     1.46385    0.770054              -0.283890 -1.224745
# 10078     1.0     1.46385    1.006993               0.337951  0.000000
# 10079     1.0     1.46385    1.243933               1.242633  1.224745
#
#        How motivated are you for being healthy\n(in %)  Body Mass Index (BMI)  \
# 0                                             0.237504              -0.592030
# 1                                             0.043670              -0.342490
# 2                                            -1.216250              -0.092950
# 3                                             0.431338               0.156589
# 4                                            -0.247081               0.406129
# ...                                                ...                    ...
# 10075                                         1.109757              -0.404250
# 10076                                         1.303591              -0.230196
# 10077                                        -0.731665              -0.056142
# 10078                                         0.915923               0.117912
# 10079                                        -1.700835               0.291966
#
#        Basal Metabolic Rate (BMR)  Body Fat Percentage (BFP)  Body Type  \
# 0                       -0.541999                  -1.298428  -0.607181
# 1                       -0.321641                  -1.017369  -0.607181
# 2                       -0.101283                  -0.736309   0.346150
# 3                        0.119074                  -0.455250   0.346150
# 4                        0.339432                  -0.174191   0.346150
# ...                           ...                        ...        ...
# 10075                   -0.455130                   0.766252  -0.607181
# 10076                   -0.301873                   0.922045  -0.607181
# 10077                   -0.148616                   1.077837   0.346150
# 10078                    0.004641                   1.233630   0.346150
# 10079                    0.157897                   1.389422   0.346150
#
#        Daily Calorie Need (Based on BMR and Exercise)\n(in Calorie)  \
# 0                                              -1.199687
# 1                                              -0.530306
# 2                                               0.179420
# 3                                               0.929492
# 4                                              -0.646370
# ...                                                  ...
# 10075                                           0.411337
# 10076                                          -1.048948
# 10077                                          -0.405851
# 10078                                           0.265307
# 10079                                           0.964525
#
#        Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)\n(in Calorie)  \
# 0                                              -1.055461
# 1                                              -0.926927
# 2                                              -0.798394
# 3                                               1.043408
# 4                                              -0.541326
# ...                                                  ...
# 10075                                           0.550863
# 10076                                           0.682325
# 10077                                           0.813787
# 10078                                           0.945249
# 10079                                           1.076710
#
#        Calorie Difference (Daily Calorie Intake - TDEE)
# 0                                             -0.168609
# 1                                             -1.307818
# 2                                             -1.023016
# 3                                             -1.545153
# 4                                             -1.478699
# ...                                                 ...
# 10075                                          1.255402
# 10076                                          0.913640
# 10077                                         -1.250857
# 10078                                         -0.510371
# 10079                                          0.571877
#
# [10080 rows x 13 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, data.iloc[:, -1], test_size=0.2, random_state=1)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((8064, 13), (2016, 13), (8064,), (2016,))

# %%
log_reg_kbest = sm.MNLogit(y_train.values.ravel(), x_train).fit()
log_reg_kbest.aic
# Out:
# Optimization terminated successfully.
#          Current function value: 0.972083
#          Iterations 8
# 15807.746588902739

# %%
log_reg_kbest.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8064
# Model:                        MNLogit   Df Residuals:                     7999
# Method:                           MLE   Df Model:                           60
# Date:                Sun, 11 Dec 2022   Pseudo R-squ.:                  0.3541
# Time:                        00:33:19   Log-Likelihood:                -7838.9
# converged:                       True   LL-Null:                       -12136.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================================================================================
#                                                                             y=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Gender                                                                              0.3895      0.104      3.738      0.000       0.185       0.594
# Height(cm)                                                                          1.6991      0.215      7.903      0.000       1.278       2.120
# Weight(kg)                                                                         -3.8164      0.519     -7.347      0.000      -4.835      -2.798
# Daily Calories Intake                                                              -4.6112      0.337    -13.664      0.000      -5.273      -3.950
# Target                                                                              2.1008      0.069     30.329      0.000       1.965       2.237
# How motivated are you for being healthy
# (in %)                                      0.2096      0.048      4.332      0.000       0.115       0.304
# Body Mass Index (BMI)                                                               4.4916      0.515      8.730      0.000       3.483       5.500
# Basal Metabolic Rate (BMR)                                                          0.1193      0.275      0.434      0.665      -0.420       0.659
# Body Fat Percentage (BFP)                                                          -0.2244      0.250     -0.896      0.370      -0.715       0.267
# Body Type                                                                          -2.1932      0.171    -12.813      0.000      -2.529      -1.858
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie)                         0.0409      0.081      0.504      0.614      -0.118       0.200
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie)     3.2579      0.248     13.139      0.000       2.772       3.744
# Calorie Difference (Daily Calorie Intake - TDEE)                                    1.7420      0.195      8.923      0.000       1.359       2.125
# ---------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                             y=2       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Gender                                                                              0.0007      0.113      0.006      0.995      -0.220       0.222
# Height(cm)                                                                          0.3703      0.250      1.482      0.138      -0.119       0.860
# Weight(kg)                                                                         -0.7957      0.549     -1.449      0.147      -1.872       0.281
# Daily Calories Intake                                                              -0.0030      0.332     -0.009      0.993      -0.654       0.648
# Target                                                                              5.7066      0.105     54.155      0.000       5.500       5.913
# How motivated are you for being healthy
# (in %)                                      0.5705      0.055     10.301      0.000       0.462       0.679
# Body Mass Index (BMI)                                                               0.6076      0.530      1.146      0.252      -0.432       1.647
# Basal Metabolic Rate (BMR)                                                          0.5756      0.284      2.023      0.043       0.018       1.133
# Body Fat Percentage (BFP)                                                           0.3149      0.279      1.129      0.259      -0.232       0.861
# Body Type                                                                          -0.9645      0.184     -5.248      0.000      -1.325      -0.604
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie)                        -0.0461      0.085     -0.539      0.590      -0.214       0.121
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie)    -0.0967      0.261     -0.371      0.711      -0.607       0.414
# Calorie Difference (Daily Calorie Intake - TDEE)                                    0.2027      0.211      0.963      0.336      -0.210       0.615
# ---------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                             y=3       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Gender                                                                              0.0148      0.087      0.169      0.866      -0.156       0.186
# Height(cm)                                                                          0.7147      0.226      3.160      0.002       0.271       1.158
# Weight(kg)                                                                         -1.8957      0.479     -3.956      0.000      -2.835      -0.956
# Daily Calories Intake                                                              -0.2260      0.257     -0.880      0.379      -0.729       0.277
# Target                                                                              0.8523      0.047     18.230      0.000       0.761       0.944
# How motivated are you for being healthy
# (in %)                                      1.1255      0.046     24.503      0.000       1.035       1.216
# Body Mass Index (BMI)                                                               0.7087      0.444      1.597      0.110      -0.161       1.579
# Basal Metabolic Rate (BMR)                                                          0.6151      0.221      2.787      0.005       0.182       1.048
# Body Fat Percentage (BFP)                                                           0.4706      0.220      2.137      0.033       0.039       0.902
# Body Type                                                                           0.6057      0.135      4.480      0.000       0.341       0.871
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie)                         0.0280      0.065      0.433      0.665      -0.098       0.154
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie)     0.1386      0.199      0.695      0.487      -0.252       0.530
# Calorie Difference (Daily Calorie Intake - TDEE)                                   -0.0766      0.167     -0.459      0.647      -0.404       0.251
# ---------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                             y=4       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Gender                                                                              0.0186      0.126      0.147      0.883      -0.229       0.266
# Height(cm)                                                                          0.9868      0.282      3.498      0.000       0.434       1.540
# Weight(kg)                                                                         -2.6379      0.620     -4.258      0.000      -3.852      -1.424
# Daily Calories Intake                                                              -0.5431      0.379     -1.433      0.152      -1.286       0.200
# Target                                                                              2.6497      0.100     26.510      0.000       2.454       2.846
# How motivated are you for being healthy
# (in %)                                      0.5898      0.062      9.497      0.000       0.468       0.712
# Body Mass Index (BMI)                                                               1.6485      0.595      2.772      0.006       0.483       2.814
# Basal Metabolic Rate (BMR)                                                          0.8231      0.315      2.611      0.009       0.205       1.441
# Body Fat Percentage (BFP)                                                           0.5253      0.310      1.696      0.090      -0.082       1.132
# Body Type                                                                          -0.4468      0.203     -2.204      0.028      -0.844      -0.049
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie)                         0.0711      0.096      0.744      0.457      -0.116       0.259
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie)     0.3215      0.292      1.101      0.271      -0.251       0.894
# Calorie Difference (Daily Calorie Intake - TDEE)                                    0.1488      0.239      0.624      0.533      -0.319       0.616
# ---------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                             y=5       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Gender                                                                             -0.2370      0.115     -2.059      0.039      -0.463      -0.011
# Height(cm)                                                                          1.0103      0.245      4.129      0.000       0.531       1.490
# Weight(kg)                                                                         -2.5829      0.544     -4.749      0.000      -3.649      -1.517
# Daily Calories Intake                                                              -2.1129      0.349     -6.057      0.000      -2.797      -1.429
# Target                                                                              5.1166      0.107     48.021      0.000       4.908       5.325
# How motivated are you for being healthy
# (in %)                                      1.2088      0.056     21.694      0.000       1.100       1.318
# Body Mass Index (BMI)                                                               1.8657      0.528      3.532      0.000       0.831       2.901
# Basal Metabolic Rate (BMR)                                                          0.9642      0.286      3.374      0.001       0.404       1.524
# Body Fat Percentage (BFP)                                                           0.8060      0.280      2.875      0.004       0.257       1.356
# Body Type                                                                          -1.4806      0.186     -7.967      0.000      -1.845      -1.116
# Daily Calorie Need (Based on BMR and Exercise)
# (in Calorie)                         0.0806      0.087      0.923      0.356      -0.091       0.252
# Total Daily Energy Expenditure (TDEE) (Based on BMR and Lifestyle)
# (in Calorie)     1.4688      0.266      5.530      0.000       0.948       1.989
# Calorie Difference (Daily Calorie Intake - TDEE)                                    0.8280      0.217      3.814      0.000       0.403       1.254
# ===================================================================================================================================================
# """

# %%
log_reg_kbest.bic
# Out:
# 16262.432313272964

# %% [markdown]
# ## Resampling Methods
#     - Using Cross validation

# %%
from sklearn.model_selection import cross_validate

lg_resultant = cross_validate(LogisticRegression(C=10, multi_class='multinomial', n_jobs=-1), 
                              x_train, 
                              y_train, 
                              cv=5,
                              return_train_score=True)

print("Mean Training Score = ", lg_resultant['train_score'].mean()*100)
print("Mean Testing Score = ", lg_resultant['test_score'].mean()*100)
# Out:
# Mean Training Score =  85.8352002212684
# Mean Testing Score =  85.40432958637867

# %% [markdown]
#     - Using Bootstrap

# %%
train_score = []
test_score = []
n_times = 10

## Performing bootstrapping
for i in range(n_times):
    
    x_train, x_test, y_train, y_test = train_test_split(X, data.iloc[:, -1], test_size=0.2, random_state=42+i)
    
    #choose from different tunable hyper parameters
    clf = LogisticRegression(C=10, multi_class='multinomial', n_jobs=-1).fit(x_train, y_train)
    y_pred = clf.predict(x_test)
 
    #Measuring accuracy on Testing Data
    Accuracy = accuracy_score(y_test, y_pred)
    
    # Storing accuracy values
    test_score.append(Accuracy)
    train_score.append(accuracy_score(y_train, clf.predict(x_train)))
    
################################################
# Result of all bootstrapping trials
print("Mean Training Score = ", np.mean(train_score)*100)
print("Mean Testing Score = ", np.mean(test_score)*100)
# Out:
# Mean Training Score =  85.84821428571429
# Mean Testing Score =  85.9672619047619
